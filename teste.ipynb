# %%
import pandas as pd

# %%
li_df = pd.read_csv('banco.csv', sep=';')
display(li_df)
# Out:
#                                             Enunciado  \
# 0   Duas operadoras oferecem planos de dados mensa...
# 1   Em determinado instante, o ângulo de elevação ...
# 2   Resolva a inequação x2 – 5x + 6 < 0 e assinale...
# 3   Um polinômio q(x), ao ser dividido por (x − 2)...
# 4   Um arquiteto projetou uma pirâmide de base qua...
# 5   Em um laboratório, uma esfera de raio 1,2 m se...
# 6   Para armazenar água da chuva em uma escola, se...
# 7   O pátio retangular da escola mede 20 m por 12 ...
# 8   Na aula de Geografia integrada à Matemática, u...
# 9   Considere um hexágono regular inscrito em uma ...
# 10  Em um experimento, a altura de um projétil (em...
#
#                                          Alternativas
# 0                                  5\n20\n40\n50\n100
# 1   Maior que 0,75 e menor que 0,78.\nMaior que 0,...
# 2   x ≤ 2\n2 < x < 3\nx < 2 ou x > 3\nx ≥ 3\ntodos...
# 3                                       0\n1\n2\n3\n4
# ...
